# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# %%
df=pd.read_csv('health_center_for_ml.csv')
df.head()
# Out:
#                           Health_Center_Name        City   State  \
# 0                       BETHEL FAMILY CLINIC      BETHEL  Alaska
# 1                        BRISTOL BAY BOROUGH      NAKNEK  Alaska
# 2    COUNCIL OF ATHABASCAN TRIBAL GOVERNMENT  FORT YUKON  Alaska
# 3  ILIULIUK FAMILY AND HEALTH SERVICES, INC.    UNALASKA  Alaska
# 4           INTERIOR COMMUNITY HEALTH CENTER   FAIRBANKS  Alaska
#
#                  County  Year Abr  Total_Patients  Children  Adults_under_65  \
# 0                Bethel  2018  AK            3563  0.620264         0.345776
# 1           Bristol Bay  2018  AK            1505  0.069767         0.844518
# 2         Yukon-Koyukuk  2018  AK            1072  0.284515         0.580224
# 3        Aleutians West  2018  AK            3565  0.121178         0.828050
# 4  Fairbanks North Star  2018  AK            5030  0.168986         0.694036
#
#    Older_Adults  ...  Colorectal_Cancer_Screening  Childhood_Immunization  \
# ...

# %%
df_as=df[df['Health Center Type']=='Administrative/Service Delivery Site']
df_admin=df[df['Health Center Type']=='Administrative']
df_service=df[df['Health Center Type']=='Service Delivery Site']

# %%
df['Total_Patients'].max()
# Out:
# 229473

# %%
# plot
fig = plt.figure(figsize=(30,12))
ax = fig.add_subplot(122, projection='3d')
ax.scatter(df_as['Older_Adults'], df_as['Hispanic_Latino_Ethnicity'], df_as['Asian'], c='skyblue', s=60)
ax.scatter(df_admin['Older_Adults'], df_admin['Hispanic_Latino_Ethnicity'], df_admin['Asian'],c='orange', s=60)
ax.scatter(df_service['Older_Adults'], df_service['Hispanic_Latino_Ethnicity'], df_service['Asian'], c='green', s=60)
ax.legend(['admin & service', 'admin','service site'], numpoints = 1)
ax.set_xlabel('Older_Adults')
ax.set_ylabel('Hispanic_Latino_Ethnicity')
ax.set_zlabel('Asian')
plt.show()

# %%
df.columns
# Out:
# Index(['Health_Center_Name', 'City', 'State', 'County', 'Year', 'Abr',
#        'Total_Patients', 'Children', 'Adults_under_65', 'Older_Adults',
#        'Racial_Ethnic_Minority', 'Hispanic_Latino_Ethnicity',
#        'African_American', 'Asian', 'American_Indian_Alaskan_Native',
#        'Native_Hawaiian_Other_Pacific_Islander', 'More_than_one_race',
#        'Best_Served_in_another_language',
#        'Patients_at_or_below_200Pct_Poverty',
#        'Patients_at_or_below_100Pct_Poverty', 'Uninsured', 'Medicaid_CHIP',
#        'Medicare', 'Other_Third_Party', 'Medical_Services', 'Dental_Services',
#        'Mental_Health_Services', 'Substance_Abuse_Services', 'Vision_Services',
#        'Enabling_Services', 'Pct_Pts_with_Hypertension',
#        'Pct_Pts_with_Diabetes', 'Pct_Pts_with_Asthma', 'Pct_Pts_with_HIV',
#        'Prenatal_Patients', 'Prenatal_Patients_who_delivered',
#        'Acces_to_Prenatal_Care', 'Pct_Births_with_Low_Birth_Weight',
#        'Cervical_Cancer_Screening',
# ...

# %% [markdown]
# X=df[[ 'Total_Patients', 'Children', 'Adults_under_65', 'Older_Adults',
#        'Racial_Ethnic_Minority', 'Hispanic_Latino_Ethnicity',
#        'African_American', 'Asian', 'American_Indian_Alaskan_Native',
#        'Native_Hawaiian_Other_Pacific_Islander', 'More_than_one_race',
#        'Best_Served_in_another_language',
#        'Patients_at_or_below_200Pct_Poverty',
#        'Patients_at_or_below_100Pct_Poverty', 'Uninsured', 'Medicaid_CHIP',
#        'Medicare', 'Other_Third_Party', 'Medical_Services', 'Dental_Services',
#        'Mental_Health_Services', 'Substance_Abuse_Services', 'Vision_Services',
#        'Enabling_Services', 'Pct_Pts_with_Hypertension',
#        'Pct_Pts_with_Diabetes', 'Pct_Pts_with_Asthma', 'Pct_Pts_with_HIV',
#        'Prenatal_Patients', 'Prenatal_Patients_who_delivered',
#        'Acces_to_Prenatal_Care', 'Pct_Births_with_Low_Birth_Weight',
#        'Cervical_Cancer_Screening',
#        'Adolescent_Weight_Screening_and_Follow Up',
#        'Adult_Weight_Screening_and_Follow Up', 'Colorectal_Cancer_Screening',
#        'Childhood_Immunization', 'Appropriate_Asthma_Treatment_Plan',
#        'Cholesterol_Treatment_Lipid_Therapy_CAD',
#        'Heart_Attack_Stroke_Treatment_Aspirin_IVD', 'Blood_Pressure_Control',
#        'Total_Cost_per_Patient']]

# %%
X=df[['State','County','Older_Adults','Hispanic_Latino_Ethnicity',
       'African_American', 'Asian', 'American_Indian_Alaskan_Native',
       'Native_Hawaiian_Other_Pacific_Islander','Health Center Type']]

# %%
X
# Out:
#               State                County  Older_Adults  \
# 0            Alaska                Bethel      0.033960
# 1            Alaska           Bristol Bay      0.085714
# 2            Alaska         Yukon-Koyukuk      0.135261
# 3            Alaska        Aleutians West      0.050771
# 4            Alaska  Fairbanks North Star      0.136978
# ...             ...                   ...           ...
# 1173  West Virginia                 Hardy      0.176714
# 1174  West Virginia                Monroe      0.208204
# 1175  West Virginia                Tucker      0.192432
# 1176        Wyoming               Laramie      0.121926
# 1177        Wyoming               Natrona      0.020725
#
#       Hispanic_Latino_Ethnicity  African_American     Asian  \
# 0                      0.014806          0.010883  0.017836
# 1                      0.153729          0.064545  0.058355
# 2                      0.000000          0.004664  0.000933
# ...

# %%
y=df['Health Center Type']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=20)

# %%
X_test.to_csv('test_origin.csv',index=False)

# %%
train_scores = []
test_scores = []
for k in range(1, 20, 2):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    train_score = knn.score(X_train, y_train)
    test_score = knn.score(X_test, y_test)
    train_scores.append(train_score)
    test_scores.append(test_score)
    print(f"k: {k}, Train/Test Score: {train_score:.3f}/{test_score:.3f}")
    
    
plt.plot(range(1, 20, 2), train_scores, marker='o')
plt.plot(range(1, 20, 2), test_scores, marker="x")
plt.xlabel("k neighbors")
plt.ylabel("Testing accuracy Score")
plt.show()
# Out:
# k: 1, Train/Test Score: 0.576/0.498
# k: 3, Train/Test Score: 0.522/0.471
# k: 5, Train/Test Score: 0.525/0.447
# k: 7, Train/Test Score: 0.522/0.458
# k: 9, Train/Test Score: 0.523/0.444
# k: 11, Train/Test Score: 0.519/0.437
# k: 13, Train/Test Score: 0.508/0.468
# k: 15, Train/Test Score: 0.498/0.468
# k: 17, Train/Test Score: 0.495/0.461
# k: 19, Train/Test Score: 0.498/0.441

# %%
knn = KNeighborsClassifier(n_neighbors=15)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=15, p=2,
#                      weights='uniform')

# %%
X_test
# Out:
#              State        County  Older_Adults  Hispanic_Latino_Ethnicity  \
# 1138  Pennsylvania  Philadelphia      0.072875                   0.876409
# 237       Oklahoma      Oklahoma      0.082430                   0.060186
# 952    Mississippi         Jones      0.080164                   0.081519
# 121        Florida        Orange      0.067263                   0.410833
# 1001   Mississippi         Jones      0.080164                   0.081519
# ...            ...           ...           ...                        ...
# 974    Mississippi         Jones      0.080164                   0.081519
# 565       Kentucky     Jefferson      0.065051                   0.209803
# 557       Kentucky         Floyd      0.142650                   0.006345
# 997    Mississippi         Jones      0.080164                   0.081519
# 106        Florida        Orange      0.067263                   0.410833
#
#       African_American     Asian  American_Indian_Alaskan_Native  \
# ...

# %%
knn.predict(X_test)
# Out:
# array(['Administrative/Service Delivery Site',
#        'Administrative/Service Delivery Site',
#        'Administrative/Service Delivery Site', 'Administrative',
#        'Administrative/Service Delivery Site', 'Service Delivery Site',
#        'Administrative/Service Delivery Site',
#        'Administrative/Service Delivery Site',
#        'Administrative/Service Delivery Site', 'Administrative',
#        'Administrative/Service Delivery Site', 'Administrative',
#        'Service Delivery Site', 'Service Delivery Site',
#        'Administrative/Service Delivery Site', 'Service Delivery Site',
#        'Administrative/Service Delivery Site',
#        'Administrative/Service Delivery Site', 'Service Delivery Site',
#        'Administrative/Service Delivery Site',
#        'Administrative/Service Delivery Site',
#        'Administrative/Service Delivery Site',
#        'Administrative/Service Delivery Site',
#        'Administrative/Service Delivery Site', 'Service Delivery Site',
# ...

# %%
a=['Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Administrative',
       'Administrative/Service Delivery Site', 'Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Administrative',
       'Administrative/Service Delivery Site', 'Administrative',
       'Service Delivery Site', 'Service Delivery Site',
       'Administrative/Service Delivery Site', 'Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Service Delivery Site',
       'Administrative/Service Delivery Site', 'Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Administrative',
       'Administrative/Service Delivery Site', 'Administrative',
       'Service Delivery Site', 'Service Delivery Site', 'Administrative',
       'Service Delivery Site', 'Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Administrative',
       'Administrative/Service Delivery Site', 'Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Service Delivery Site',
       'Service Delivery Site', 'Administrative/Service Delivery Site',
       'Service Delivery Site', 'Administrative',
       'Administrative/Service Delivery Site', 'Administrative',
       'Administrative', 'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Service Delivery Site',
       'Administrative/Service Delivery Site', 'Administrative',
       'Administrative', 'Service Delivery Site', 'Service Delivery Site',
       'Administrative/Service Delivery Site', 'Administrative',
       'Administrative', 'Administrative/Service Delivery Site',
       'Administrative', 'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Administrative',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Administrative',
       'Administrative', 'Administrative/Service Delivery Site',
       'Administrative', 'Service Delivery Site',
       'Administrative/Service Delivery Site', 'Administrative',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Administrative',
       'Administrative', 'Administrative/Service Delivery Site',
       'Service Delivery Site', 'Administrative/Service Delivery Site',
       'Service Delivery Site', 'Service Delivery Site', 'Administrative',
       'Administrative', 'Administrative',
       'Administrative/Service Delivery Site', 'Administrative',
       'Administrative/Service Delivery Site', 'Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Administrative',
       'Administrative/Service Delivery Site', 'Service Delivery Site',
       'Administrative', 'Administrative',
       'Administrative/Service Delivery Site', 'Service Delivery Site',
       'Administrative', 'Administrative/Service Delivery Site',
       'Administrative', 'Administrative/Service Delivery Site',
       'Service Delivery Site', 'Administrative/Service Delivery Site',
       'Administrative', 'Administrative/Service Delivery Site',
       'Service Delivery Site', 'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Administrative',
       'Service Delivery Site', 'Administrative',
       'Administrative/Service Delivery Site', 'Administrative',
       'Service Delivery Site', 'Service Delivery Site', 'Administrative',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Service Delivery Site',
       'Administrative', 'Service Delivery Site', 'Administrative',
       'Service Delivery Site', 'Administrative',
       'Administrative/Service Delivery Site', 'Administrative',
       'Administrative', 'Administrative',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Service Delivery Site',
       'Administrative/Service Delivery Site', 'Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Service Delivery Site',
       'Administrative/Service Delivery Site', 'Service Delivery Site',
       'Administrative', 'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Administrative',
       'Service Delivery Site', 'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Service Delivery Site',
       'Service Delivery Site', 'Administrative', 'Administrative',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Administrative',
       'Administrative/Service Delivery Site', 'Administrative',
       'Administrative', 'Service Delivery Site', 'Service Delivery Site',
       'Administrative', 'Administrative/Service Delivery Site',
       'Service Delivery Site', 'Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Administrative',
       'Administrative/Service Delivery Site', 'Administrative',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Service Delivery Site',
       'Administrative', 'Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Administrative',
       'Service Delivery Site', 'Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Administrative',
       'Administrative', 'Administrative',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Administrative',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Service Delivery Site',
       'Administrative', 'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Service Delivery Site',
       'Administrative/Service Delivery Site', 'Administrative',
       'Administrative/Service Delivery Site', 'Service Delivery Site',
       'Service Delivery Site', 'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Administrative',
       'Service Delivery Site', 'Administrative/Service Delivery Site',
       'Administrative', 'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Service Delivery Site',
       'Administrative/Service Delivery Site', 'Administrative',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Service Delivery Site',
       'Administrative', 'Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Administrative',
       'Administrative/Service Delivery Site', 'Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Service Delivery Site',
       'Administrative', 'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Service Delivery Site',
       'Administrative', 'Administrative', 'Administrative',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Administrative',
       'Administrative', 'Administrative',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site',
       'Administrative/Service Delivery Site', 'Administrative',
       'Administrative', 'Administrative/Service Delivery Site',
       'Service Delivery Site', 'Service Delivery Site',
       'Administrative/Service Delivery Site', 'Administrative']

# %%
a_df=pd.DataFrame(a)
a_df
# Out:
#                                         0
# 0    Administrative/Service Delivery Site
# 1    Administrative/Service Delivery Site
# 2    Administrative/Service Delivery Site
# 3                          Administrative
# 4    Administrative/Service Delivery Site
# ..                                    ...
# 290  Administrative/Service Delivery Site
# 291                 Service Delivery Site
# 292                 Service Delivery Site
# 293  Administrative/Service Delivery Site
# 294                        Administrative
#
# [295 rows x 1 columns]

# %%
test_origin=pd.read_csv('test_origin.csv')
combine=pd.concat([test_origin,a_df],axis=1)
test_final=combine.rename(columns={0:'Test Result'})
test_final.to_csv('test_final.csv',index=False)

# %%
test=pd.read_csv('All_Years_County_Health_Ranking_Data.csv')
test.head()
# Out:
#      FIPS    State County/Borough/Parish  Year Health_Outcomes_Rank  \
# 0  1000.0  Alabama                     0  2020                    0
# 1  1001.0  Alabama               Autauga  2020                  6.0
# 2  1003.0  Alabama               Baldwin  2020                  2.0
# 3  1005.0  Alabama               Barbour  2020                 45.0
# 4  1007.0  Alabama                  Bibb  2020                 34.0
#
#    Yrs_Potential_Life_Lost_per_100K  Percent_Fair_Poor_Health  \
# 0                       9942.794666                 22.028703
# 1                       8128.591190                 20.882987
# 2                       7354.122530                 17.509134
# 3                      10253.573403                 29.591802
# 4                      11977.539484                 19.439724
#
#    Percent_Low_Birthweight_Births  Percent_Adult_Smokers  \
# 0                       10.254871              20.927353
# 1                        8.619529              18.081557
# ...

# %%
test.columns
# Out:
# Index(['FIPS', 'State', 'County/Borough/Parish', 'Year',
#        'Health_Outcomes_Rank', 'Yrs_Potential_Life_Lost_per_100K',
#        'Percent_Fair_Poor_Health', 'Percent_Low_Birthweight_Births',
#        'Percent_Adult_Smokers', 'Percent_Adult_Obesity',
#        'Healthy_Food_Access_Index', 'Percent_Adults_Physical_Inactivity',
#        'Percent_Access_to_Excercise_Opportunities',
#        'Percent_Adults_Excessive_Drinking',
#        'Percent_Driving_Deaths_with_Alcohol_Involvement',
#        'Chlamydia_Cases_per_100K', 'Teen_Birth_Rate',
#        'Percent_Ppl_Under65_w/o_Insurance', 'PCP_per_100K',
#        'Dentists_per_100K', 'MHP_per_100K',
#        'Preventable_Hospitalization_Rate_per_100K_Medicare', 'Graduation_Rate',
#        'Percent_Adults_with_Some_Post-secondary_Ed',
#        'Percent_Unemployed_&_Looking_for_Work',
#        'Percent_Children_Living_in_Poverty', '80th_Percentile_MHI',
#        '20th_Percentile_MHI',
# ...

# %%
test=test[['State','County/Borough/Parish','Year','Percent_Age_65_and_over','Percent_Hispanic','Percent_Non-Hispanic_Black_or_African_American','Percent_Asian',
               'Percent_American_Indian_or_Alaskan_Native','Percent_Native_Hawaiian_Other_Pacific_Islander']]

# %%
X=df[[ 'Older_Adults','Hispanic_Latino_Ethnicity',
       'African_American', 'Asian', 'American_Indian_Alaskan_Native',
       'Native_Hawaiian_Other_Pacific_Islander']]

# %%
test_TX=test[test['State']=='Texas']
test_TX
# Out:
#        State County/Borough/Parish  Year  Percent_Age_65_and_over  \
# 2566   Texas                     0  2020                12.550831
# 2567   Texas              Anderson  2020                14.797527
# 2568   Texas               Andrews  2020                10.359665
# 2569   Texas              Angelina  2020                16.325265
# 2570   Texas               Aransas  2020                29.627606
# ...      ...                   ...   ...                      ...
# 18772  Texas                  Wood  2015                26.426512
# 18773  Texas                Yoakum  2015                11.937928
# 18774  Texas                 Young  2015                19.126547
# 18775  Texas                Zapata  2015                11.195274
# 18776  Texas                Zavala  2015                12.471208
#
#        Percent_Hispanic  Percent_Non-Hispanic_Black_or_African_American  \
# 2566          39.610168                                       11.991020
# ...

# %%
len(test_TX['County/Borough/Parish'].unique())
# Out:
# 255

# %%
df_hcall=pd.read_csv('Health_Center_Data_2016_to_2018.csv')
df_hcall_tx=df_hcall[df_hcall['State']=='Texas']
len(df_hcall_tx['County'].unique())
# Out:
# 49

# %%
df_hc=pd.read_csv('health center.csv')
df_hc_tx=df_hc[df_hc['State']=='TX']
len(df_hc_tx['County'].unique())
# Out:
# 126

# %%
df_hc_tx
# Out:
#                                                Site Name  \
# 16                    CENTROMED SOUTH PARK DENTAL CLINIC
# 22                           Wellness Pointe - Pine Tree
# 25                               Care Connections Clinic
# 39     Community Healthcare Center - Juarez Medical C...
# 50        Gulf Coast Health Center, Inc. - Jasper Dental
# ...                                                  ...
# 28340                           Bee Busy Wellness Center
# 28344                                 Mobile Dental Unit
# 28391                                    HSNT - Loop 288
# 28411               NUESTRA CLINICA DEL VALLE - MERCEDES
# 28414                   Springdale Women's Health Center
#
#       Services Delivered at Site                    Health Center Type  \
# 16                           Yes                 Service Delivery Site
# 22                           Yes                 Service Delivery Site
# ...

# %%
health_centers_county_rank = 
health_centers_county_rank[ cols_to_move + [ col for col in health_centers_county_rank.columns if col not in cols_to_move ] ]

# %%
df_TX=df[df['State']=='Texas']
df_TX
# Out:
#                                Health_Center_Name         City  State  \
# 1150  BRAZOS VALLEY COMMUNITY ACTION AGENCY, INC.  COLLEGE STA  Texas
# 1151                           CENTRO SAN VICENTE      EL PASO  Texas
# 1152  COMMUNITY ACTION CORPORATION OF SOUTH TEXAS        ALICE  Texas
# 1153                  FRONTERA HEALTHCARE NETWORK         EDEN  Texas
# 1154                   PROJECT VIDA HEALTH CENTER      EL PASO  Texas
# 1155     SOUTH PLAINS RURAL HEALTH SERVICES, INC.    LEVELLAND  Texas
# 1156      SOUTH TEXAS RURAL HEALTH SERVICES, INC.      COTULLA  Texas
#
#          County  Year Abr  Total_Patients  Children  Adults_under_65  \
# 1150     Brazos  2018  TX           42064  0.359714         0.533710
# 1151    El Paso  2018  TX           16771  0.122771         0.703357
# 1152  Jim Wells  2018  TX           15898  0.297019         0.559945
# 1153     Concho  2018  TX            6832  0.185890         0.519174
# ...

# %%
test_TX_X=test_TX[['Percent_Age_65_and_over','Percent_Hispanic','Percent_Non-Hispanic_Black_or_African_American','Percent_Asian',
                   'Percent_American_Indian_or_Alaskan_Native','Percent_Native_Hawaiian_Other_Pacific_Islander']]

# %%
test_TX_X
# Out:
#        Percent_Age_65_and_over  Percent_Hispanic  \
# 2566                 12.550831         39.610168
# 2567                 14.797527         17.965103
# 2568                 10.359665         56.641659
# 2569                 16.325265         22.492307
# 2570                 29.627606         27.429388
# ...                        ...               ...
# 18772                26.426512          9.334373
# 18773                11.937928         62.365591
# 18774                19.126547         17.376370
# 18775                11.195274         93.509382
# 18776                12.471208         92.859493
#
#        Percent_Non-Hispanic_Black_or_African_American  Percent_Asian  \
# 2566                                        11.991020       5.178294
# 2567                                        20.958713       0.930120
# 2568                                         1.334951       0.772286
# 2569                                        14.833739       1.077022
# ...

# %%
knn.predict(test_TX_X)
# Out:
# array(['Administrative/Service Delivery Site',
#        'Administrative/Service Delivery Site',
#        'Administrative/Service Delivery Site',
#        'Administrative/Service Delivery Site',
#        'Administrative/Service Delivery Site',
#        'Administrative/Service Delivery Site',
#        'Administrative/Service Delivery Site',
#        'Administrative/Service Delivery Site',
#        'Administrative/Service Delivery Site',
#        'Administrative/Service Delivery Site',
#        'Administrative/Service Delivery Site',
#        'Administrative/Service Delivery Site',
#        'Administrative/Service Delivery Site',
#        'Administrative/Service Delivery Site',
#        'Administrative/Service Delivery Site',
#        'Administrative/Service Delivery Site',
#        'Administrative/Service Delivery Site',
#        'Administrative/Service Delivery Site',
#        'Administrative/Service Delivery Site',
#        'Administrative/Service Delivery Site',
# ...

# %%
len(knn.predict(test_TX_X))
# Out:
# 255

# %%
test_final=pd.read_csv('test_final.csv')
test_final
# Out:
#             State        County  Older_Adults  Hispanic_Latino_Ethnicity  \
# 0    Pennsylvania  Philadelphia      0.072875                   0.876409
# 1        Oklahoma      Oklahoma      0.082430                   0.060186
# 2     Mississippi         Jones      0.080164                   0.081519
# 3         Florida        Orange      0.067263                   0.410833
# 4     Mississippi         Jones      0.080164                   0.081519
# ..            ...           ...           ...                        ...
# 290   Mississippi         Jones      0.080164                   0.081519
# 291      Kentucky     Jefferson      0.065051                   0.209803
# 292      Kentucky         Floyd      0.142650                   0.006345
# 293   Mississippi         Jones      0.080164                   0.081519
# 294       Florida        Orange      0.067263                   0.410833
#
#      African_American     Asian  American_Indian_Alaskan_Native  \
# ...

# %%
match=[]
for index, row in test_final.iterrows():
    if row['Health Center Type']==row['Test Result']:
        match.append(row['County'])
match
# Out:
# ['Jones',
#  'Orange',
#  'Darke',
#  'Orange',
#  'Jefferson',
#  'Oklahoma',
#  'Jefferson',
#  'Jones',
#  'Oklahoma',
#  'Kalamazoo',
#  'Jefferson',
#  'Oklahoma',
#  'Jones',
#  'Kings',
#  'Kalamazoo',
#  'Oklahoma',
#  'Jefferson',
#  'Oklahoma',
#  'Orange',
#  'Carbon',
#  'Montmorency',
#  'Kalamazoo',
#  'Cook',
#  'Brazos',
#  'Oklahoma',
#  'Jefferson',
#  'Oklahoma',
#  'Jefferson',
#  'Oklahoma',
#  'Salt Lake',
#  'Salt Lake',
#  'Kalamazoo',
#  'Oklahoma',
#  'Kalamazoo',
#  'Kalamazoo',
#  'Salt Lake',
#  'Orange',
#  'Salt Lake',
#  'Orange',
#  'Kalamazoo',
#  'Orange',
#  'Jefferson',
#  'Salt Lake',
#  'Woodbury',
#  'Jones',
#  'Kalamazoo',
#  'Jones',
#  'Oklahoma',
#  'Orange',
#  'Jones',
#  'Jefferson',
#  'Orange',
#  'Jones',
#  'Jefferson',
#  'Salt Lake',
#  'Salt Lake',
#  'Oklahoma',
#  'Cook',
#  'Worcester',
#  'Kalamazoo',
#  'Jefferson',
#  'Jones',
#  'Jefferson',
#  'Jefferson',
#  'Jones',
#  'Delaware',
#  'Orange',
#  'Orange',
#  'Jones',
# ...

# %%
match_result=pd.DataFrame(match)
len(match_result)
# Out:
# 138

# %%
138/295
# Out:
# 0.46779661016949153

# %%
for index, row in df.iterrows():
    print(row['c1'], row['c2'])

# %%
X = np.arange(295)
fig = plt.figure()
ax = fig.add_axes([1,1,2,2])
ax.bar(X + 0.00, test_final['Health Center Type'], color = 'b', width = 0.25)
ax.bar(X + 0.25, test_final['Test Result'], color = 'g', width = 0.25)
